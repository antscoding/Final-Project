# %% [markdown]
# # The Best Neighborhood in Pitt
# ### Group - I Have no Idea
#
# ### Three Datasets Chosen:
# - Public Drinking Water Fountains
# - Fire Incidents
# - Firearm Incidents

# %%
### Dataset: Fire Incidents

# %%
import pandas as pd
fire = pd.read_csv('fire_incidents.csv', sep='\t')
